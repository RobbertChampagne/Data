# %% [markdown]
# # Filtering Columns and Rows

# %% [markdown]
# - `axis=0`: This means the operation is performed along the rows (down the columns).
# - `axis=1`: This means the operation is performed along the columns (across the rows).

# %%
import pandas as pd
df = pd.read_csv("../datasets/small_olympic.csv").head()
df
# Out:
#    athlete_id                name     sex              born  height  weight  \
# 0       65649       Ivanka Bonova  Female      4 April 1949   166.0    55.0
# 1      112510   Nataliya Uryadova  Female     15 March 1977   184.0    70.0
# 2      114973  Essa Ismail Rashed    Male  14 December 1986   165.0    55.0
# 3       30359         Péter Boros    Male   12 January 1908     NaN     NaN
# 4       50557      Rudolf Piowatý    Male     28 April 1900     NaN     NaN
#
#                country country_noc  \
# 0             Bulgaria         BUL
# 1   Russian Federation         RUS
# 2                Qatar         QAT
# 3              Hungary         HUN
# 4       Czechoslovakia         TCH
#
#                                          description  \
# 0                 Personal Best: 400 – 53.54 (1980).
# 1                                                NaN
# 2            Personal Best: 10000 – 27:20.97 (2006).
# 3  Between 1927 and 1938, Péter Boros competed as...
# 4  Rudolf Piowaty joined the Czechoslovak militar...
#
#                                        special_notes
# 0                                                NaN
# 1  Listed in Olympians Who Won a Medal at the Eur...
# 2  Listed in Olympians Who Won a Medal at the Asi...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# #### Check if certain values are in a column

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

# Strip any leading/trailing whitespace and ensure case matches
#df["country"] = df["country"].str.strip()

# Define specific countries
specific_countries = [" Qatar", " Hungary"]

# Filter DataFrame
filtered_df = df[df["country"].isin(specific_countries)]

# Display the filtered DataFrame
filtered_df
# Out:
#    athlete_id                name   sex              born  height  weight  \
# 2      114973  Essa Ismail Rashed  Male  14 December 1986   165.0    55.0
# 3       30359         Péter Boros  Male   12 January 1908     NaN     NaN
#
#     country country_noc                                        description  \
# 2     Qatar         QAT            Personal Best: 10000 – 27:20.97 (2006).
# 3   Hungary         HUN  Between 1927 and 1938, Péter Boros competed as...
#
#                                        special_notes
# 2  Listed in Olympians Who Won a Medal at the Asi...
# 3                                                NaN

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

# Filter DataFrame
df[df["country"].str.contains(" Bulgaria") & df["sex"].str.contains("Female")]
# Out:
#    athlete_id           name     sex          born  height  weight    country  \
# 0       65649  Ivanka Bonova  Female  4 April 1949   166.0    55.0   Bulgaria
#
#   country_noc                         description special_notes
# 0         BUL  Personal Best: 400 – 53.54 (1980).           NaN

# %% [markdown]
# #### Set new index.

# %% [markdown]
# The `inplace=True` parameter: meaning that the operation is performed directly on the original DataFrame without creating a new one.

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

df.set_index("country", inplace=True)

df.head()
# Out:
#                     athlete_id                name     sex              born  \
# country
# Bulgaria                 65649       Ivanka Bonova  Female      4 April 1949
# Russian Federation      112510   Nataliya Uryadova  Female     15 March 1977
# Qatar                   114973  Essa Ismail Rashed    Male  14 December 1986
# Hungary                  30359         Péter Boros    Male   12 January 1908
# Czechoslovakia           50557      Rudolf Piowatý    Male     28 April 1900
#
#                     height  weight country_noc  \
# country
# Bulgaria             166.0    55.0         BUL
# Russian Federation   184.0    70.0         RUS
# Qatar                165.0    55.0         QAT
# Hungary                NaN     NaN         HUN
# Czechoslovakia         NaN     NaN         TCH
#
#                                                           description  \
# country
# Bulgaria                           Personal Best: 400 – 53.54 (1980).
# Russian Federation                                                NaN
# Qatar                         Personal Best: 10000 – 27:20.97 (2006).
# Hungary             Between 1927 and 1938, Péter Boros competed as...
# Czechoslovakia      Rudolf Piowaty joined the Czechoslovak militar...
#
#                                                         special_notes
# country
# Bulgaria                                                          NaN
# Russian Federation  Listed in Olympians Who Won a Medal at the Eur...
# Qatar               Listed in Olympians Who Won a Medal at the Asi...
# Hungary                                                           NaN
# Czechoslovakia                                                    NaN

# %% [markdown]
# #### Filtering Rows by Index

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

# Set 'country' as the index
df.set_index("country", inplace=True)

# Filter rows by index
filtered_rows = df.filter(like="Qatar", axis=0)

filtered_rows
# Out:
#          athlete_id                name   sex              born  height  \
# country
# Qatar        114973  Essa Ismail Rashed  Male  14 December 1986   165.0
#
#          weight country_noc                              description  \
# country
# Qatar      55.0         QAT  Personal Best: 10000 – 27:20.97 (2006).
#
#                                              special_notes
# country
# Qatar    Listed in Olympians Who Won a Medal at the Asi...

# %% [markdown]
# #### Filtering Rows and Columns Simultaneously

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

# Filter rows where the country is Qatar and select the country and name columns
filtered_rows_columns = df[df["country"] == " Qatar"][["country", "name"]]

filtered_rows_columns
# Out:
#   country                name
# 2   Qatar  Essa Ismail Rashed

# %% [markdown]
# #### Filtering Columns by Function

# %%
df = pd.read_csv("../datasets/small_olympic.csv")
filtered_columns_func = df.filter(axis=1, like="name")
filtered_columns_func.head()
# Out:
#                  name
# 0       Ivanka Bonova
# 1   Nataliya Uryadova
# 2  Essa Ismail Rashed
# 3         Péter Boros
# 4      Rudolf Piowatý

# %% [markdown]
# #### Sort values by 'weight' in ascending order

# %%
df = pd.read_csv("../datasets/small_olympic.csv")
df[df["weight"] < 90].sort_values("weight", ascending=True).head()
# Out:
#     athlete_id                  name     sex              born  height  \
# 0        65649         Ivanka Bonova  Female      4 April 1949   166.0
# 2       114973    Essa Ismail Rashed    Male  14 December 1986   165.0
# 14      146013        Raquel Queirós  Female      4 March 2000   167.0
# 7       110425           Tanja Morel  Female    4 October 1975   164.0
# 15      109912  Vyacheslav Kurginyan    Male  22 December 1986   170.0
#
#     weight              country country_noc  \
# 0     55.0             Bulgaria         BUL
# 2     55.0                Qatar         QAT
# 14    56.0             Portugal         POR
# 7     58.0          Switzerland         SUI
# 15    65.0   Russian Federation         RUS
#
#                                 description  \
# 0        Personal Best: 400 – 53.54 (1980).
# 2   Personal Best: 10000 – 27:20.97 (2006).
# 14                                      NaN
# 7                                       NaN
# 15                                      NaN
#
#                                         special_notes
# 0                                                 NaN
# 2   Listed in Olympians Who Won a Medal at the Asi...
# 14                                                NaN
# 7   Listed in Olympians Who Won a Medal at the Eur...
# 15  Listed in Olympians Who Won a Medal at the Eur...

# %% [markdown]
# ---

# %% [markdown]
# ### The primary difference between `.loc` and `.iloc`.

# %% [markdown]
# **`.loc[]`** (Label-based Indexing)<br>
# .loc accessor in pandas is used to access a group of rows and columns by labels or a boolean array.<br>
# It is primarily label-based, which means that you use row and column labels to select data.
#
# `df.loc[row_labels, column_labels]`
#
# **row_labels**: The labels of the rows you want to select.<br>
# **column_labels**: The labels of the columns you want to select.

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

# %% [markdown]
# #### Accessing a Single Row by Label

# %%
# Set the 'name' column as the index so .loc can find the label
df.set_index("name", inplace=True)

df.loc["Ivanka Bonova"]
# Out:
# athlete_id                                    65649
# sex                                          Female
# born                                   4 April 1949
# height                                        166.0
# weight                                         55.0
# country                                    Bulgaria
# country_noc                                     BUL
# description      Personal Best: 400 – 53.54 (1980).
# special_notes                                   NaN
# Name: Ivanka Bonova, dtype: object

# %% [markdown]
# #### Accessing a Single Column by Label

# %%
# the `:` symbol is used to select all rows or columns
df.loc[:, "country"].head()
# Out:
# athlete_id
# 65649                Bulgaria
# 112510     Russian Federation
# 114973                  Qatar
# 30359                 Hungary
# 50557          Czechoslovakia
# Name: country, dtype: object

# %% [markdown]
# #### Accessing a Specific Cell

# %%
# Set the 'name' column as the index so .loc can find the label
df.set_index("name", inplace=True)

df.loc["Ivanka Bonova", "country"]
# Out:
# ' Bulgaria'

# %% [markdown]
# #### Slicing Rows and Columns

# %%
df = pd.read_csv("../datasets/small_olympic.csv")
df.set_index("athlete_id", inplace=True)

df.loc[65649:30359, "name":"weight"]
# Out:
#                           name     sex              born  height  weight
# athlete_id
# 65649            Ivanka Bonova  Female      4 April 1949   166.0    55.0
# 112510       Nataliya Uryadova  Female     15 March 1977   184.0    70.0
# 114973      Essa Ismail Rashed    Male  14 December 1986   165.0    55.0
# 30359              Péter Boros    Male   12 January 1908     NaN     NaN

# %% [markdown]
# #### Boolean Indexing

# %%
# Access rows where 'values' column is greater than 4
df.loc[df["weight"] > 60].head()
# Out:
#                          name     sex              born  height  weight  \
# athlete_id
# 112510      Nataliya Uryadova  Female     15 March 1977   184.0    70.0
# 133041       Vincent Riendeau    Male  13 December 1996   178.0    68.0
# 110705        Maksim Shabalin    Male   25 January 1982   183.0    76.0
# 56266          Go Yeong-Chang    Male     21 March 1926   167.0    75.0
# 93334         Craig Hutchison    Male       26 May 1975   198.0    97.0
#
#                         country country_noc description  \
# athlete_id
# 112510       Russian Federation         RUS         NaN
# 133041                   Canada         CAN         NaN
# 110705       Russian Federation         RUS         NaN
# 56266         Republic of Korea         KOR         NaN
# 93334                    Canada         CAN         NaN
#
#                                                 special_notes
# athlete_id
# 112510      Listed in Olympians Who Won a Medal at the Eur...
# 133041      Listed in Olympians Who Won a Medal at the Sum...
# 110705      Listed in Olympians Who Won a Medal at the Eur...
# 56266                                                     NaN
# 93334       Listed in Olympians Who Won a Medal at the Pan...

# %% [markdown]
# **`.iloc[]`** (Integer-based Indexing)
#
# **Integer-based**: Uses integer positions to select data.
#
# **Excludes End**: When slicing, the start index is included, but the end index is excluded.
#
# **Boolean Indexing**: Can use boolean arrays to filter data.

# %% [markdown]
# #### Access the first three rows and the first two columns

# %%
df.iloc[:3, :2]
# Out:
#                           name     sex
# athlete_id
# 65649            Ivanka Bonova  Female
# 112510       Nataliya Uryadova  Female
# 114973      Essa Ismail Rashed    Male

# %% [markdown]
# ---

# %% [markdown]
# # Group By and Aggregate Functions

# %%
df = pd.read_csv("../datasets/small_olympic.csv")

# %% [markdown]
# `.agg()` : is used to apply one or more aggregation functions (mean, sum, ..) to the columns of a DataFrame.
#
#
# It is often used in conjunction with the `groupby()` method to perform group-wise operations.

# %% [markdown]
# ####  Group By a Single Column and Aggregate

# %%
df.groupby("sex").agg({"height": "mean", "weight": "mean"})
# Out:
#         height  weight
# sex
# Female   169.6    61.2
# Male     179.9    75.3

# %% [markdown]
# #### Group By Multiple Columns and Aggregate

# %% [markdown]
# `.size()` : It computes the size of each group, i.e., the number of rows in each group.

# %%
df.groupby(["sex", "country"]).size()
# Out:
# sex     country
# Female  Bulgaria              1
#         East Germany          1
#         France                1
#         Great Britain         1
#         Portugal              1
#         ROC                   1
#         Russian Federation    1
#         Switzerland           1
# Male    Canada                2
#         Czechoslovakia        1
#         France                1
#         Great Britain         1
#         Hungary               1
#         Italy                 1
#         Japan                 1
#         Luxembourg            1
#         Netherlands           2
#         Qatar                 1
#         Republic of Korea     1
#         Russian Federation    2
# dtype: int64

# %% [markdown]
# `.reset_index()` : to convert the Series back into a DataFrame. By default, the group keys become the index of the Series. It moves these index values back into columns, and the original index is replaced with a default integer index.

# %%
df.groupby(["sex", "country"]).size().reset_index(name="count")
# Out:
#        sex              country  count
# 0   Female             Bulgaria      1
# 1   Female         East Germany      1
# 2   Female               France      1
# 3   Female        Great Britain      1
# 4   Female             Portugal      1
# 5   Female                  ROC      1
# 6   Female   Russian Federation      1
# 7   Female          Switzerland      1
# 8     Male               Canada      2
# 9     Male       Czechoslovakia      1
# 10    Male               France      1
# 11    Male        Great Britain      1
# 12    Male              Hungary      1
# 13    Male                Italy      1
# 14    Male                Japan      1
# 15    Male           Luxembourg      1
# 16    Male          Netherlands      2
# 17    Male                Qatar      1
# 18    Male    Republic of Korea      1
# 19    Male   Russian Federation      2

# %%
df.groupby(["sex", "country"])["weight"].mean().reset_index()
# Out:
#        sex              country  weight
# 0   Female             Bulgaria    55.0
# 1   Female         East Germany     NaN
# 2   Female               France    67.0
# 3   Female        Great Britain     NaN
# 4   Female             Portugal    56.0
# 5   Female                  ROC     NaN
# 6   Female   Russian Federation    70.0
# 7   Female          Switzerland    58.0
# 8     Male               Canada    82.5
# 9     Male       Czechoslovakia     NaN
# 10    Male               France    85.0
# 11    Male        Great Britain     NaN
# 12    Male              Hungary     NaN
# 13    Male                Italy     NaN
# 14    Male                Japan    70.0
# 15    Male           Luxembourg    86.0
# 16    Male          Netherlands    76.0
# 17    Male                Qatar    55.0
# 18    Male    Republic of Korea    75.0
# 19    Male   Russian Federation    70.5

# %% [markdown]
# #### Using Different Aggregation Functions

# %%
df.groupby("sex").agg({"height": ["mean", "sum"], "weight": ["mean", "sum"]})
# Out:
#        height         weight
#          mean     sum   mean    sum
# sex
# Female  169.6   848.0   61.2  306.0
# Male    179.9  1799.0   75.3  753.0

# %% [markdown]
# #### Applying Custom Aggregation Functions

# %%
def custom_agg(x):
    return x.max() - x.min()


df.groupby("sex").agg({"height": custom_agg, "weight": custom_agg})
# Out:
#         height  weight
# sex
# Female    20.0    15.0
# Male      33.0    42.0
